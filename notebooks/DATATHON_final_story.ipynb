# %% [markdown]
# # DATATHON Final Story Figures
# Notebook sạch để tái lập 4 hình chính trong report. Notebook exploration đầy đủ nên để ở `notebooks/archive/`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.eda.final_story_charts import run_all
run_all(data_dir=ROOT / 'data', out_dir=ROOT / 'outputs' / 'figures' / 'main')
